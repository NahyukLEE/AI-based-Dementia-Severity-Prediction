# %%
import shutil
import os

# %%
# %pwd
# Out:
# 'C:\\Users\\user\\Desktop\\AI-based-Dementia-Severity-Prediction\\preprocessing'

# %%
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\SNSB_fig_total_CAUandBD\SNSB_fig_CAU\SNSB_png'
os.chdir(path_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8bb59713c945> in <module>
#       1 path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\SNSB_fig_total_CAUandBD\SNSB_fig_CAU\SNSB_png'
# ----> 2 os.chdir(path_dir)
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'C:\\Users\\user\\Desktop\\AI-based-Dementia-Severity-Prediction\\SNSB_fig_total_CAUandBD\\SNSB_fig_CAU\\SNSB_png'

# %%
# %pwd
# Out:
# 'C:\\Users\\user\\Desktop\\AI-based-Dementia-Severity-Prediction\\preprocessing'

# %%
file_list = os.listdir()

# %%
print('디렉토리 내 전체 데이터 개수 :', len(file_list))
# Out:
# 디렉토리 내 전체 데이터 개수 : 7512

# %%
count = 0
for i in file_list :
    if (i[-3:] in ['PNG', 'png']) and ('_' in i) :
        count+=1
print('유효 데이터 개수 :', count, '/', len(file_list))
# Out:
# 유효 데이터 개수 : 7505 / 7512

# %%
count_sum = 0
for n in range(1,8):
    count = 0
    for i in file_list :
        if (i[-3:] in ['PNG', 'png']) and ('_%d' %n in i) and ('(' not in i) and (len(i) == 14) :
            count += 1
            count_sum += 1
    print('검사%d 데이터 수 :' %n, count)
print('총 검사 데이터 수 :', count_sum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c09c9cf58a06> in <module>
#       2 for n in range(1,8):
#       3     count = 0
# ----> 4     for i in file_list :
#       5         if (i[-3:] in ['PNG', 'png']) and ('_%d' %n in i) and ('(' not in i) and (len(i) == 14) :
#       6             count += 1
#
# NameError: name 'file_list' is not defined

# %%
count_sum = 0
for n in range(1,8):
    count = 0
    for i in file_list :
        if (i[-3:] in ['PNG', 'png']) and ('_%d' %n in i) and ('(' not in i) and (len(i) == 14) :
            shutil.copy(i, r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\%d' %n)
            count+=1
    print('복사 된 검사%d 데이터 수 :' %n, count)
# Out:
# 복사 된 검사1 데이터 수 : 951
# 복사 된 검사2 데이터 수 : 951
# 복사 된 검사3 데이터 수 : 916
# 복사 된 검사4 데이터 수 : 915
# 복사 된 검사5 데이터 수 : 959
# 복사 된 검사6 데이터 수 : 960
# 복사 된 검사7 데이터 수 : 959

# %%
for n in range(1,8):
    path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\%d' %n
    os.chdir(path_dir)
    file_list = os.listdir()
    print('전처리 후 검사 %d 데이터 개수 :' %n, len(file_list))
# Out:
# 전처리 후 검사 1 데이터 개수 : 951
# 전처리 후 검사 2 데이터 개수 : 951
# 전처리 후 검사 3 데이터 개수 : 916
# 전처리 후 검사 4 데이터 개수 : 915
# 전처리 후 검사 5 데이터 개수 : 959
# 전처리 후 검사 6 데이터 개수 : 960
# 전처리 후 검사 7 데이터 개수 : 959

# %%
# 검사 1 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\1'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_1 = []
for i in file_list :
    if (i[-6:] in ['_1.PNG', '_1.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_1.append(i[0:8])
assert len(hospital_no_1) == len(set(hospital_no_1)) == count
print(len(hospital_no_1), hospital_no_1[0:10])
# Out:
# 951 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
# 검사 2 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\2'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_2 = []
for i in file_list :
    if (i[-6:] in ['_2.PNG', '_2.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_2.append(i[0:8])
assert len(hospital_no_2) == len(set(hospital_no_2)) == count
print(len(hospital_no_2), hospital_no_2[0:10])
# Out:
# 951 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
# 검사 3 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\3'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_3 = []
for i in file_list :
    if (i[-6:] in ['_3.PNG', '_3.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_3.append(i[0:8])
assert len(hospital_no_3) == len(set(hospital_no_3)) == count
print(len(hospital_no_3), hospital_no_3[0:10])
# Out:
# 916 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
# 검사 4 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\4'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_4 = []
for i in file_list :
    if (i[-6:] in ['_4.PNG', '_4.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_4.append(i[0:8])
assert len(hospital_no_4) == len(set(hospital_no_4)) == count
print(len(hospital_no_4), hospital_no_4[0:10])
# Out:
# 915 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
# 검사 5 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\5'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_5 = []
for i in file_list :
    if (i[-6:] in ['_5.PNG', '_5.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_5.append(i[0:8])
assert len(hospital_no_5) == len(set(hospital_no_5)) == count
print(len(hospital_no_5), hospital_no_5[0:10])
# Out:
# 959 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
# 검사 6 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\6'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_6 = []
for i in file_list :
    if (i[-6:] in ['_6.PNG', '_6.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_6.append(i[0:8])
assert len(hospital_no_6) == len(set(hospital_no_6)) == count
print(len(hospital_no_6), hospital_no_6[0:10])
# Out:
# 960 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
# 검사 7 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\7'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_7 = []
for i in file_list :
    if (i[-6:] in ['_7.PNG', '_7.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_7.append(i[0:8])
assert len(hospital_no_7) == len(set(hospital_no_7)) == count
print(len(hospital_no_7), hospital_no_7[0:10])
# Out:
# 959 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
intersection = list(set(hospital_no_1) & set(hospital_no_2) & set(hospital_no_3) & set(hospital_no_4) & set(hospital_no_5) & set(hospital_no_6) & set(hospital_no_7))

# %%
len(intersection)
# Out:
# 891

# %%
intersection
# Out:
# ['01031821',
#  '00297688',
#  '00191216',
#  '00743073',
#  '00270362',
#  '00910838',
#  '00406528',
#  '01268097',
#  '01171046',
#  '00699051',
#  '01153388',
#  '01142886',
#  '01208946',
#  '00857366',
#  '01305736',
#  '00945423',
#  '00664961',
#  '01077626',
#  '00812029',
#  '01210535',
#  '01224642',
#  '01397646',
#  '00759679',
#  '00507383',
#  '01242449',
#  '01031085',
#  '01332712',
#  '00762879',
#  '00784417',
#  '00484899',
#  '01305203',
#  '00601028',
#  '00181474',
#  '00666473',
#  '01146683',
#  '01007523',
#  '01261387',
#  '00502785',
#  '01250004',
#  '00474262',
#  '01418995',
#  '00605706',
#  '00649045',
#  '00839465',
#  '01418548',
#  '00891889',
#  '00225424',
#  '00614960',
#  '00784418',
#  '00784778',
#  '00786814',
#  '00360427',
#  '00909061',
#  '00265634',
#  '00917762',
#  '00948785',
#  '01262449',
#  '01033535',
#  '00651601',
#  '01278381',
#  '00396894',
#  '01131959',
#  '00257196',
#  '00873628',
#  '00623289',
#  '00845032',
# ...

# %%
for n in range(1,8):
    print('##### ENTER #%d #####' %n)
    path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\%d' %n
    os.chdir(path_dir)
    file_list = os.listdir()

    del_count = 0
    for i in file_list :
        if i[0:8] in intersection :
            pass
        else :
            os.remove(i)
            del_count += 1
    print('삭제 데이터 수 :', del_count)
    print('최종 데이터 수 :', len(os.listdir()))
# Out:
# ##### ENTER #1 #####
# 삭제 데이터 수 : 0
# 최종 데이터 수 : 891
# ##### ENTER #2 #####
# 삭제 데이터 수 : 60
# 최종 데이터 수 : 891
# ##### ENTER #3 #####
# 삭제 데이터 수 : 25
# 최종 데이터 수 : 891
# ##### ENTER #4 #####
# 삭제 데이터 수 : 24
# 최종 데이터 수 : 891
# ##### ENTER #5 #####
# 삭제 데이터 수 : 68
# 최종 데이터 수 : 891
# ##### ENTER #6 #####
# 삭제 데이터 수 : 69
# 최종 데이터 수 : 891
# ##### ENTER #7 #####
# 삭제 데이터 수 : 68
# 최종 데이터 수 : 891

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\preprocessing'
os.chdir(path_dir)

df = pd.read_csv('SNSB_1_figure.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of       고유번호 Hospital No  Age  sex education  edu_years  Rey_CFT_copy_score  \
# 0     2285    00938443   75    0        대졸       14.0                17.0
# 1     2284    01407055   85    1       고중퇴       11.0                 1.5
# 2     2283    00970997   80    0        고졸       12.0                36.0
# 3     2282    00991395   75    0     초4~6년        6.0                26.0
# 4     2281    00891889   73    0        고졸       12.0                18.0
# ...    ...         ...  ...  ...       ...        ...                 ...
# 2226     9    00804535   71    0     초4~6년        6.0                 1.5
# 2227     8    00804535   70    0     초4~6년        6.0                14.5
# 2228     6    01076477   80    0     초4~6년        4.0                31.0
# 2229     5    00735018   48    0        중졸        9.0                31.5
# 2230     4    00735018   49    0        중졸        9.0                27.5
#
# ...

# %%
count = 0
for i in range(len(df)):
    if df.loc[i]['Hospital No'] in intersection :
        count += 1
print(count)
# Out:
# 1150

# %%
len(intersection)
# Out:
# 891

# %%
df.duplicated(['Hospital No'], keep=False).value_counts()
# Out:
# False    1477
# True      754
# dtype: int64

# %%
new_df = df.drop_duplicates(['Hospital No'], keep=False)

# %%
new_df = new_df.reset_index()

# %%
new_df
# Out:
#       index  고유번호 Hospital No  Age  sex education  edu_years  \
# 0         0  2285    00938443   75    0        대졸       14.0
# 1         1  2284    01407055   85    1       고중퇴       11.0
# 2         3  2282    00991395   75    0     초4~6년        6.0
# 3         5  2280    00930331   63    0       대중퇴       13.0
# 4         6  2279    01244209   82    1     초1~3년        2.0
# ...     ...   ...         ...  ...  ...       ...        ...
# 1472   2222    14    01074925   57    1        대졸       16.0
# 1473   2223    13    00265352   75    1        고졸       12.0
# 1474   2224    12    00999096   74    0        중졸        9.0
# 1475   2225    11    00784541   60    0     초4~6년        6.0
# 1476   2228     6    01076477   80    0     초4~6년        4.0
#
#       Rey_CFT_copy_score  Rey_CFT_copy_score_p  \
# 0                   17.0                  0.00
# 1                    1.5                  0.00
# 2                   26.0                 31.10
# ...

# %%
count = 0
new_intersection = []
for i in range(len(new_df)):
    if new_df.loc[i]['Hospital No'] in intersection :
        new_intersection.append(new_df.loc[i]['Hospital No'])
        count += 1
print(count)
# Out:
# 668

# %%
assert count == len(new_intersection)
new_intersection
# Out:
# ['00938443',
#  '01407055',
#  '00991395',
#  '00930331',
#  '01244209',
#  '00884635',
#  '00782437',
#  '01418995',
#  '00270362',
#  '00406495',
#  '00707209',
#  '00845032',
#  '00869860',
#  '00794793',
#  '00815396',
#  '00606325',
#  '00711517',
#  '00611747',
#  '00844259',
#  '00998156',
#  '00855327',
#  '00275902',
#  '01077768',
#  '00701694',
#  '00622249',
#  '01186214',
#  '00386210',
#  '01464462',
#  '01137650',
#  '01444938',
#  '00600530',
#  '01034585',
#  '00297688',
#  '00904296',
#  '01383688',
#  '00192974',
#  '00454294',
#  '00621597',
#  '00813676',
#  '00778555',
#  '01439234',
#  '01397646',
#  '01450546',
#  '00743257',
#  '01133279',
#  '01219378',
#  '01320922',
#  '00956149',
#  '00687556',
#  '01124557',
#  '00955842',
#  '01457505',
#  '01462198',
#  '01353330',
#  '00951712',
#  '01453571',
#  '00856489',
#  '01360770',
#  '00773865',
#  '00745597',
#  '00889931',
#  '00394200',
#  '01298366',
#  '00834803',
#  '01261387',
#  '00723110',
# ...

# %%
for n in range(1,8):
    print('##### ENTER #%d #####' %n)
    path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\%d' %n
    os.chdir(path_dir)
    file_list = os.listdir()

    del_count = 0
    for i in file_list :
        if i[0:8] in new_intersection :
            pass
        else :
            os.remove(i)
            del_count += 1
    print('삭제 데이터 수 :', del_count)
    print('최종 데이터 수 :', len(os.listdir()))
# Out:
# ##### ENTER #1 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668
# ##### ENTER #2 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668
# ##### ENTER #3 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668
# ##### ENTER #4 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668
# ##### ENTER #5 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668
# ##### ENTER #6 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668
# ##### ENTER #7 #####
# 삭제 데이터 수 : 223
# 최종 데이터 수 : 668

# %%
new_df.tail()
# Out:
#       index  고유번호 Hospital No  Age  sex education  edu_years  \
# 1472   2222    14    01074925   57    1        대졸       16.0
# 1473   2223    13    00265352   75    1        고졸       12.0
# 1474   2224    12    00999096   74    0        중졸        9.0
# 1475   2225    11    00784541   60    0     초4~6년        6.0
# 1476   2228     6    01076477   80    0     초4~6년        4.0
#
#       Rey_CFT_copy_score  Rey_CFT_copy_score_p  \
# 1472                35.0                 63.18
# 1473                 7.0                  0.00
# 1474                29.0                 26.40
# 1475                31.0                 44.70
# 1476                31.0                 71.07
#
#      Alternating_square_and_triangle  ... K_TMT_E_A_success  K_TMT_E_A_error  \
# 1472                          Normal  ...           Success              0.0
# 1473                        Deformed  ...           Success              0.0
# ...

# %%
new_intersection
# Out:
# ['00938443',
#  '01407055',
#  '00991395',
#  '00930331',
#  '01244209',
#  '00884635',
#  '00782437',
#  '01418995',
#  '00270362',
#  '00406495',
#  '00707209',
#  '00845032',
#  '00869860',
#  '00794793',
#  '00815396',
#  '00606325',
#  '00711517',
#  '00611747',
#  '00844259',
#  '00998156',
#  '00855327',
#  '00275902',
#  '01077768',
#  '00701694',
#  '00622249',
#  '01186214',
#  '00386210',
#  '01464462',
#  '01137650',
#  '01444938',
#  '00600530',
#  '01034585',
#  '00297688',
#  '00904296',
#  '01383688',
#  '00192974',
#  '00454294',
#  '00621597',
#  '00813676',
#  '00778555',
#  '01439234',
#  '01397646',
#  '01450546',
#  '00743257',
#  '01133279',
#  '01219378',
#  '01320922',
#  '00956149',
#  '00687556',
#  '01124557',
#  '00955842',
#  '01457505',
#  '01462198',
#  '01353330',
#  '00951712',
#  '01453571',
#  '00856489',
#  '01360770',
#  '00773865',
#  '00745597',
#  '00889931',
#  '00394200',
#  '01298366',
#  '00834803',
#  '01261387',
#  '00723110',
# ...

# %%
count = 0
for i in range(len(new_df)):
    if new_df.loc[i]['Hospital No'] in new_intersection :
        pass
    else :
        new_df= new_df.drop(i)

# %%
new_df = new_df.reset_index()

# %%
new_df['Hospital No'].tolist() == new_intersection
# Out:
# True

# %%
new_df
# Out:
#      level_0  index  고유번호 Hospital No  Age  sex education  edu_years  \
# 0          0      0  2285    00938443   75    0        대졸       14.0
# 1          1      1  2284    01407055   85    1       고중퇴       11.0
# 2          2      3  2282    00991395   75    0     초4~6년        6.0
# 3          3      5  2280    00930331   63    0       대중퇴       13.0
# 4          4      6  2279    01244209   82    1     초1~3년        2.0
# ..       ...    ...   ...         ...  ...  ...       ...        ...
# 663     1010   1444   814    00164098   72    1       대중퇴       16.0
# 664     1011   1445   813    00693697   72    0     초4~6년        6.0
# 665     1013   1448   810    01194553   53    0     초4~6년        6.0
# 666     1014   1451   807    00339832   55    1        고졸       12.0
# 667     1057   1522   736    01146683   63    0     초1~3년        3.0
#
#      Rey_CFT_copy_score  Rey_CFT_copy_score_p  ... K_TMT_E_A_success  \
# ...

# %%
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\preprocessing'
os.chdir(path_dir)
new_df.to_csv("final_668.csv", index=False, encoding="utf-8-sig")

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 29 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   level_0                          668 non-null    int64
#  1   index                            668 non-null    int64
#  2   고유번호                             668 non-null    int64
#  3   Hospital No                      668 non-null    object
#  4   Age                              668 non-null    int64
#  5   sex                              668 non-null    int64
#  6   education                        667 non-null    object
#  7   edu_years                        668 non-null    float64
#  8   Rey_CFT_copy_score               664 non-null    float64
#  9   Rey_CFT_copy_score_p             664 non-null    float64
#  10  Alternating_square_and_triangle  620 non-null    object
#  11  Luria_loop                       618 non-null    object
# ...
