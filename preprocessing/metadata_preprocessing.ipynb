# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('final_668.csv')

# %%
df.tail()
# Out:
#      고유번호  Hospital No  Age  sex education  edu_years  Rey_CFT_copy_score  \
# 663   814       164098   72    1       대중퇴       16.0                33.0
# 664   813       693697   72    0     초4~6년        6.0                 5.5
# 665   810      1194553   53    0     초4~6년        6.0                24.0
# 666   807       339832   55    1        고졸       12.0                27.5
# 667   736      1146683   63    0     초1~3년        3.0                28.0
#
#      Rey_CFT_copy_score_p Alternating_square_and_triangle Luria_loop  ...  \
# 663                 38.03                        Deformed     Normal  ...
# 664                  0.00                             PSV        PSV  ...
# 665                  0.43                             NaN        NaN  ...
# 666                  0.18                          Normal     Normal  ...
# 667                 35.44                          Normal     Normal  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   고유번호                             668 non-null    int64
#  1   Hospital No                      668 non-null    int64
#  2   Age                              668 non-null    int64
#  3   sex                              668 non-null    int64
#  4   education                        667 non-null    object
#  5   edu_years                        668 non-null    float64
#  6   Rey_CFT_copy_score               664 non-null    float64
#  7   Rey_CFT_copy_score_p             664 non-null    float64
#  8   Alternating_square_and_triangle  620 non-null    object
#  9   Luria_loop                       618 non-null    object
#  10  K_MMSE_drawing                   667 non-null    float64
#  11  K_MMSE_drawing_p                 667 non-null    object
# ...

# %%
df.dropna(subset=['CDR', 'Sum_of_boxes'], inplace = True)
df.drop(['CDT_Contour', 'CDT_Numbers', 'CDT_time_setting', 'CDT_Total_score', 'CDT_Total_score_p'], axis = 1, inplace = True)

# %%
df.drop(['Global_DS', 'K_IADL_Score'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 664 entries, 0 to 667
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   고유번호                             664 non-null    int64
#  1   Hospital No                      664 non-null    int64
#  2   Age                              664 non-null    int64
#  3   sex                              664 non-null    int64
#  4   education                        663 non-null    object
#  5   edu_years                        664 non-null    float64
#  6   Rey_CFT_copy_score               661 non-null    float64
#  7   Rey_CFT_copy_score_p             661 non-null    float64
#  8   Alternating_square_and_triangle  617 non-null    object
#  9   Luria_loop                       615 non-null    object
#  10  K_MMSE_drawing                   664 non-null    float64
#  11  K_MMSE_drawing_p                 664 non-null    object
# ...
