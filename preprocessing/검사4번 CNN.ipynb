# %%
import shutil
import os

# %%
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\raw_data\SNSB_png'
os.chdir(path_dir)

# %%
file_list = os.listdir()

# %%
print('디렉토리 내 전체 데이터 개수 :', len(file_list))
# Out:
# 디렉토리 내 전체 데이터 개수 : 7512

# %%
count = 0
for i in file_list :
    if (i[-3:] in ['PNG', 'png']) and ('_' in i) :
        count+=1
print('유효 데이터 개수 :', count, '/', len(file_list))
# Out:
# 유효 데이터 개수 : 7505 / 7512

# %%
count_sum = 0
for n in range(1,8):
    count = 0
    for i in file_list :
        if (i[-3:] in ['PNG', 'png']) and ('_%d' %n in i) and ('(' not in i) and (len(i) == 14) :
            count += 1
            count_sum += 1
    print('검사%d 데이터 수 :' %n, count)
print('총 검사 데이터 수 :', count_sum)
# Out:
# 검사1 데이터 수 : 951
# 검사2 데이터 수 : 951
# 검사3 데이터 수 : 916
# 검사4 데이터 수 : 915
# 검사5 데이터 수 : 959
# 검사6 데이터 수 : 960
# 검사7 데이터 수 : 959
# 총 검사 데이터 수 : 6611

# %%
count_sum = 0
for n in range(1,8):
    count = 0
    for i in file_list :
        if (i[-3:] in ['PNG', 'png']) and ('_%d' %n in i) and ('(' not in i) and (len(i) == 14) :
            shutil.copy(i, r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\%d' %n)
            count+=1
    print('복사 된 검사%d 데이터 수 :' %n, count)
# Out:
# 복사 된 검사1 데이터 수 : 951
# 복사 된 검사2 데이터 수 : 951
# 복사 된 검사3 데이터 수 : 916
# 복사 된 검사4 데이터 수 : 915
# 복사 된 검사5 데이터 수 : 959
# 복사 된 검사6 데이터 수 : 960
# 복사 된 검사7 데이터 수 : 959

# %%
# 검사 4 기준 환자 번호 리스트 제작
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\dataset\4'
os.chdir(path_dir)
file_list = os.listdir()

count = 0
hospital_no_4 = []
for i in file_list :
    if (i[-6:] in ['_4.PNG', '_4.png']) :
        count += 1
    assert len(i) == 14
    hospital_no_4.append(i[0:8])
assert len(hospital_no_4) == len(set(hospital_no_4)) == count
print(len(hospital_no_4), hospital_no_4[0:10])
# Out:
# 915 ['00000323', '00001809', '00018693', '00028236', '00041427', '00048377', '00050941', '00058064', '00076105', '00088360']

# %%
import pandas as pd
import warnings
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
warnings.filterwarnings('ignore')

# %%
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\preprocessing'
os.chdir(path_dir)

# %%
df = pd.read_csv('SNSB_1_figure_for4.csv')

# %%
df
# Out:
#       고유번호 Hospital No Luria_loop  CDR  Sum_of_boxes
# 0     2285      938443     Normal  1.0           8.0
# 1     2284     1407055     Normal  1.0           6.0
# 2     2283      970997     Normal  0.5           1.5
# 3     2282      991395     Normal  0.5           2.5
# 4     2281      891889     Normal  0.5           2.5
# ...    ...         ...        ...  ...           ...
# 2226     9      804535        PSV  1.0           4.5
# 2227     8      804535        PSV  1.0           4.5
# 2228     6     1076477     Normal  2.0          10.0
# 2229     5      735018     Normal  0.5           2.0
# 2230     4      735018     Normal  0.5           2.5
#
# [2231 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231 entries, 0 to 2230
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   고유번호          2231 non-null   int64
#  1   Hospital No   2229 non-null   object
#  2   Luria_loop    2051 non-null   object
#  3   CDR           2213 non-null   float64
#  4   Sum_of_boxes  2206 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 87.3+ KB

# %%
df.drop(['CDR', 'Sum_of_boxes'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231 entries, 0 to 2230
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   고유번호         2231 non-null   int64
#  1   Hospital No  2229 non-null   object
#  2   Luria_loop   2051 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 52.4+ KB

# %%
df.dropna(subset=['Luria_loop', 'Hospital No'], inplace = True)

# %%
df.reset_index(inplace=True)

# %%
df.drop(['index'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   고유번호         2050 non-null   int64
#  1   Hospital No  2050 non-null   object
#  2   Luria_loop   2050 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 48.2+ KB

# %%
hospital_no_4 = list(map(int, hospital_no_4))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2049 entries, 0 to 2048
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   고유번호         2049 non-null   int64
#  1   Hospital No  2049 non-null   object
#  2   Luria_loop   2049 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 48.1+ KB

# %%
for i in range(len(df)):
    print()
    if int(df.loc[i]['Hospital No']) in hospital_no_4:
        pass
    else:
        print('ab')
# Out:
# ab
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ab
#
#
#
#
#
#
#
#
#
# ab
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ab
#
#
#
# ab
#
#
# ab
#
#
# ab
#
# ab
#
#
#
#
#
# ab
#
# ab
#
# ab
#
#
# ab
#
# ab
#
#
#
# ab
#
# ab
#
# ab
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
# ab
#
#
# ab
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
# ab
#
#
# ab
#
# ab
#
# ab
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ab
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
# ab
#
# ab
#
# ab
#
# ab
#
#
#
# ab
#
#
#
#
#
#
#
#
#
#
# ab
#
# ab
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
# ab
#
#
#
#
#
#
#
#
#
#
#
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
# ab
#
#
#
# ...

# %%
for i in range(len(df)):
    if int(df.loc[i]['Hospital No']) in hospital_no_4:
        pass
    else:
        df.drop(index=i, axis=0, inplace=True)

# %%
df
# Out:
#       고유번호 Hospital No Luria_loop
# 0     2285      938443     Normal
# 1     2284     1407055     Normal
# 2     2283      970997     Normal
# 3     2282      991395     Normal
# 4     2281      891889     Normal
# ...    ...         ...        ...
# 1986    69      112176     Normal
# 1992    63      403084        PSV
# 2008    47      853607     Normal
# 2009    46      853607     Normal
# 2011    44      899380     Normal
#
# [1089 rows x 3 columns]

# %%
df.drop_duplicates(['Hospital No'], keep=False, inplace = True)

# %%
len(list(df['Hospital No'])) == len(set(df['Hospital No'])) == 666
# Out:
# True

# %%
arr = list(df['Hospital No'])

# %%
arr
# Out:
# [938443,
#  1407055,
#  991395,
#  930331,
#  1244209,
#  884635,
#  782437,
#  270362,
#  406495,
#  707209,
#  845032,
#  869860,
#  794793,
#  815396,
#  606325,
#  711517,
#  611747,
#  998156,
#  855327,
#  275902,
#  1077768,
#  701694,
#  622249,
#  386210,
#  1464462,
#  1137650,
#  1444938,
#  600530,
#  1034585,
#  297688,
#  904296,
#  1383688,
#  192974,
#  1088674,
#  454294,
#  621597,
#  813676,
#  743257,
#  1320922,
#  956149,
#  687556,
#  1124557,
#  1457505,
#  1353330,
#  951712,
#  1453571,
#  856489,
#  1360770,
#  773865,
#  889931,
#  394200,
#  1298366,
#  834803,
#  723110,
#  780973,
#  1451391,
#  486105,
#  674106,
#  735480,
#  1238327,
#  1453856,
#  308691,
#  942023,
#  826861,
#  832911,
#  474121,
#  1436758,
#  1006707,
#  766838,
#  1001138,
#  325929,
#  640147,
#  779511,
#  1443011,
#  671540,
#  721815,
#  1429282,
#  1033535,
#  861148,
#  813343,
#  1101799,
#  605972,
#  1074516,
#  88360,
#  1159856,
#  1328203,
#  876362,
#  1391231,
# ...

# %%
print('##### ENTER #####')
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\preprocessing\4'
os.chdir(path_dir)
file_list = os.listdir()

del_count = 0
for i in file_list :
    if int(i[0:8]) in arr :
        pass
    else :
        os.remove(i)
        del_count += 1
print('삭제 데이터 수 :', del_count)
print('최종 데이터 수 :', len(os.listdir()))
# Out:
# ##### ENTER #####
# 삭제 데이터 수 : 249
# 최종 데이터 수 : 666

# %%
file_list = os.listdir()
new_arr = []
for i in file_list :
    new_arr.append(int(i[0:8]))

# %%
set(arr) == set(new_arr)
# Out:
# True

# %%
df.drop(['고유번호'], axis=1, inplace=True)

# %%
df['Luria_loop'].value_counts()
# Out:
# Normal        541
# PSV            76
# Deformed       28
# Deform&PSV     21
# Name: Luria_loop, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Hospital No  666 non-null    object
#  1   Luria_loop   666 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
path_dir = r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\preprocessing\4'
os.chdir(path_dir)
file_list = os.listdir()
len(file_list)
# Out:
# 666

# %%
normal = list(map(int, list(df[df['Luria_loop'] == 'Normal']['Hospital No'])))
len(normal)
# Out:
# 541

# %%
PSV = list(map(int, list(df[df['Luria_loop'] == 'PSV']['Hospital No'])))
len(PSV)
# Out:
# 76

# %%
deformed = list(map(int, list(df[df['Luria_loop'] == 'Deformed']['Hospital No'])))
len(deformed)
# Out:
# 28

# %%
deformPSV = list(map(int, list(df[df['Luria_loop'] == 'Deform&PSV']['Hospital No'])))
len(deformPSV)
# Out:
# 21

# %%
for i in file_list :
    if int(i[0:8]) in normal:
        shutil.copy(i, r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\CNN\Normal')
    elif int(i[0:8]) in PSV:
        shutil.copy(i, r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\CNN\PSV')
    elif int(i[0:8]) in deformed:
        shutil.copy(i, r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\CNN\Deformed')
    elif int(i[0:8]) in deformPSV:
        shutil.copy(i, r'C:\Users\user\Desktop\AI-based-Dementia-Severity-Prediction\CNN\Deform&PSV')
    else :
        print('ERROR! with %s' %i)
